# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('E Commerce Dataset.xlsx', sheet_name='E Comm')

df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
df.describe()
# Out:
#          CustomerID        Churn       Tenure     CityTier  WarehouseToHome  \
# count   5630.000000  5630.000000  5630.000000  5630.000000      5630.000000
# mean   52815.500000     0.168384    10.134103     1.654707        15.566785
# std     1625.385339     0.374240     8.357951     0.915389         8.345961
# min    50001.000000     0.000000     0.000000     1.000000         5.000000
# 25%    51408.250000     0.000000     3.000000     1.000000         9.000000
# 50%    52815.500000     0.000000     9.000000     1.000000        14.000000
# 75%    54222.750000     0.000000    15.000000     3.000000        20.000000
# max    55630.000000     1.000000    61.000000     3.000000       127.000000
#
#        HourSpendOnApp  NumberOfDeviceRegistered  SatisfactionScore  \
# count     5630.000000               5630.000000        5630.000000
# mean         2.934636                  3.688988           3.066785
# std          0.705528                  1.023999           1.380194
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# DaySinceLastOrder              307
# OrderAmountHikeFromlastYear    265
# Tenure                         264
# OrderCount                     258
# CouponUsed                     256
# HourSpendOnApp                 255
# WarehouseToHome                251
# CustomerID                       0
# MaritalStatus                    0
# Complain                         0
# NumberOfAddress                  0
# PreferedOrderCat                 0
# SatisfactionScore                0
# Churn                            0
# NumberOfDeviceRegistered         0
# Gender                           0
# PreferredPaymentMode             0
# CityTier                         0
# PreferredLoginDevice             0
# CashbackAmount                   0
# dtype: int64

# %%
# Separate columns
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

# Fill numeric with median
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# Fill categorical with mode
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
df.isnull().sum()
# Out:
# CustomerID                     0
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %%
df['Churn'].value_counts()
# Out:
# Churn
# 0    4682
# 1     948
# Name: count, dtype: int64

# %%
df['Churn'].mean()
# Out:
# np.float64(0.16838365896980462)

# %%
df.groupby('Churn')[['Tenure', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount']].mean()
# Out:
#           Tenure  OrderCount  DaySinceLastOrder  CashbackAmount
# Churn
# 0      11.404528    2.992952           4.709739      180.635203
# 1       3.859705    2.808017           3.222574      160.370928

# %%
df.groupby('PreferredLoginDevice')['Churn'].mean()
# Out:
# PreferredLoginDevice
# Computer        0.198286
# Mobile Phone    0.125859
# Phone           0.224208
# Name: Churn, dtype: float64

# %%
df.groupby('PreferredPaymentMode')['Churn'].mean()
# Out:
# PreferredPaymentMode
# CC                  0.216117
# COD                 0.287671
# Cash on Delivery    0.154362
# Credit Card         0.128581
# Debit Card          0.153846
# E wallet            0.228013
# UPI                 0.173913
# Name: Churn, dtype: float64

# %%
df.groupby('Gender')['Churn'].mean()
# Out:
# Gender
# Female    0.154942
# Male      0.177305
# Name: Churn, dtype: float64

# %%
df.groupby('Complain')['Churn'].mean()
# Out:
# Complain
# 0    0.109290
# 1    0.316708
# Name: Churn, dtype: float64

# %%
sns.boxplot(x='Churn', y='Tenure', data=df)
plt.show()

# %%
sns.boxplot(x='Churn', y='OrderCount', data=df)
plt.show()

# %%
def risk_category(row):
    if row['Tenure'] < 5 and row['Complain'] == 1:
        return "High Risk"
    elif row['Tenure'] < 5:
        return "Medium Risk"
    else:
        return "Low Risk"

df['RiskCategory'] = df.apply(risk_category, axis=1)

# %%
df['CustomerValue'] = pd.qcut(df['CashbackAmount'], 3, labels=["Low Value", "Medium Value", "High Value"])

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()
